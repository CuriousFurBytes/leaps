# %% [markdown]
# # {{NOTEBOOK_TITLE}}
#
# **Module:** {{MODULE_NUMBER}}: {{MODULE_NAME}}
# **Topic:** {{TOPIC_NAME}}
# **Difficulty:** {{DIFFICULTY}}
# **Estimated time:** {{HOURS}} hours
# **Created:** {{YYYY-MM-DD}}
#
# ---
#
# ## Overview
#
# {{NOTEBOOK_OVERVIEW}}
#
# This notebook explores {{CORE_CONCEPT}} through interactive demonstrations and exercises.
# You should work through it top-to-bottom, running each cell in order.
#
# ## Learning Objectives
#
# By the end of this notebook, you will:
#
# 1. {{LEARNING_OBJECTIVE_1}}
# 2. {{LEARNING_OBJECTIVE_2}}
# 3. {{LEARNING_OBJECTIVE_3}}
#
# ## Prerequisites
#
# Before running this notebook, make sure you have:
#
# - [ ] Read the module README: `module-{{MODULE_NUMBER}}-{{MODULE_SLUG}}/README.md`
# - [ ] Understood the Core Concepts section
# - [ ] Set up the learning environment (see `devcontainer.json` or `Dockerfile` at topic root)
# - [ ] {{ADDITIONAL_PREREQUISITE}}
#
# ---
#
# **How to use this notebook:**
# - Run cells with `Shift+Enter`
# - Modify values and re-run to see how outputs change
# - Write your own code in the Exercise and Challenge cells
# - Add markdown cells with your own notes and observations

# %% [markdown]
# ## Theory
#
# {{THEORY_OVERVIEW}}
#
# ### Key Idea
#
# {{KEY_IDEA_EXPLANATION}}
#
# ### Mathematical Foundation _(if applicable)_
#
# The core relationship we'll be working with:
#
# $${{EQUATION_OR_FORMULA}}$$
#
# Where:
# - ${{VAR_1}}$ = {{VAR_1_MEANING}}
# - ${{VAR_2}}$ = {{VAR_2_MEANING}}
# - ${{VAR_3}}$ = {{VAR_3_MEANING}}
#
# ### Why This Matters
#
# {{WHY_THIS_THEORY_MATTERS}}
#
# > **Note:** The goal here is *intuition*, not memorization.
# > Focus on understanding what each piece means, not on the formula itself.

# %%
# =============================================================================
# Setup — Run this cell first
# Uncomment the packages you need; comment out ones you don't
# =============================================================================

# Core scientific computing
import numpy as np
# import scipy as sp
# from scipy import stats, optimize, linalg

# Visualization
import matplotlib.pyplot as plt
import matplotlib as mpl
# import seaborn as sns
# import plotly.express as px

# Data handling
# import pandas as pd

# Symbolic math
# import sympy as sym
# sym.init_printing()

# Standard library
import math
import random
from typing import List, Tuple, Optional

# Notebook configuration
# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')
mpl.rcParams['figure.figsize'] = (10, 6)
mpl.rcParams['font.size'] = 12

# Reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

print('Setup complete.')
print(f'NumPy version: {np.__version__}')
print(f'Matplotlib version: {mpl.__version__}')

# %% [markdown]
# ## Demonstrations
#
# The following cells demonstrate the core concepts from the module.
# **Run each cell, read the output, and make sure you understand what's happening before moving on.**
#
# ### Demonstration 1: {{DEMO_1_TITLE}}
#
# {{DEMO_1_EXPLANATION}}

# %%
# Demonstration 1: {{DEMO_1_TITLE}}
# -------------------------------------------------------
# {{DEMO_1_CODE_COMMENT}}

# TODO: Replace this placeholder with a real demonstration
# that illustrates {{CORE_CONCEPT}} clearly.

# Example structure:
# 1. Set up the scenario
# 2. Apply the concept
# 3. Visualize or print the result
# 4. Point out what to notice

x = np.linspace(0, 10, 100)  # Replace with relevant data
y = np.sin(x)                # Replace with relevant computation

plt.figure(figsize=(10, 4))
plt.plot(x, y, label='{{LABEL_1}}')
plt.xlabel('{{X_LABEL}}')
plt.ylabel('{{Y_LABEL}}')
plt.title('{{DEMO_1_TITLE}}')
plt.legend()
plt.tight_layout()
plt.show()

# Key observation to print
print('Key observation:')
print('{{DEMO_1_KEY_OBSERVATION}}')

# %% [markdown]
# ## Interactive Examples
#
# **These cells are designed for you to modify and re-run.**
#
# Change the parameter values in the cells below, re-run them (`Shift+Enter`),
# and observe how the output changes. This is the best way to build intuition.
#
# ### Interactive Example 1: How {{PARAMETER_1}} Affects the Output
#
# Experiment: change `{{PARAMETER_1}}` below and observe what happens.
# - What happens when you make it very large? Very small?
# - Is there a critical threshold where behavior changes?
# - What does this tell you about the underlying concept?

# %%
# Interactive Example 1: Vary {{PARAMETER_1}}
# -------------------------------------------------------
# Try changing PARAM_1 and re-running this cell.
# Suggested values to try: {{SUGGESTED_VALUES}}

PARAM_1 = {{DEFAULT_PARAM_1_VALUE}}   # <-- CHANGE THIS
PARAM_2 = {{DEFAULT_PARAM_2_VALUE}}   # <-- CHANGE THIS

# TODO: Replace with interactive demonstration
x = np.linspace(0, 10, 200)
y = PARAM_1 * np.sin(PARAM_2 * x)    # Replace with real formula

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(x, y)
ax1.set_title(f'{{DEMO_TITLE}} (param_1={PARAM_1}, param_2={PARAM_2})')
ax1.set_xlabel('{{X_LABEL}}')
ax1.set_ylabel('{{Y_LABEL}}')

# Second panel: something that changes with the parameters
ax2.bar(['{{METRIC_1}}', '{{METRIC_2}}', '{{METRIC_3}}'],
        [PARAM_1, PARAM_2, PARAM_1 * PARAM_2])
ax2.set_title('Parameter Summary')

plt.tight_layout()
plt.show()

print(f'With PARAM_1={PARAM_1} and PARAM_2={PARAM_2}:')
print(f'  Result metric 1: {PARAM_1 * PARAM_2:.4f}')  # Replace with real metric
print(f'  Result metric 2: {np.max(np.abs(y)):.4f}')  # Replace with real metric

# %% [markdown]
# ## Exercises
#
# Now it's your turn. Complete the exercises below **without looking at the solution cells**.
#
# Each exercise builds on the demonstrations above. If you're stuck:
# 1. Re-read the relevant section in the module README
# 2. Re-run the demonstration cells and trace through what they do
# 3. Check the EXERCISES.md file for hints
#
# ---
#
# ### Exercise 1: {{EXERCISE_1_TITLE}} [Easy]
#
# **Task:** {{EXERCISE_1_TASK}}
#
# **Requirements:**
# - {{EXERCISE_1_REQUIREMENT_1}}
# - {{EXERCISE_1_REQUIREMENT_2}}
#
# **Expected output:**
# ```
# {{EXERCISE_1_EXPECTED_OUTPUT}}
# ```

# %%
# Exercise 1: {{EXERCISE_1_TITLE}}
# -------------------------------------------------------

# TODO: Write your solution here

# YOUR CODE HERE


# When you're done, run this cell and check that the output matches
# the expected output in the markdown cell above.

# %% [markdown]
# ## Challenges
#
# These problems go beyond the module content. They're optional but valuable.
#
# > There is no single correct solution. Focus on reasoning and exploration.
#
# ### Challenge: {{CHALLENGE_TITLE}}
#
# {{CHALLENGE_DESCRIPTION}}
#
# **Open-ended questions to explore:**
# - {{CHALLENGE_QUESTION_1}}
# - {{CHALLENGE_QUESTION_2}}
# - {{CHALLENGE_QUESTION_3}}

# %%
# Challenge: {{CHALLENGE_TITLE}}
# -------------------------------------------------------
# This is open-ended. Explore freely.

# YOUR CODE HERE


# When you have results, add a markdown cell below this one
# describing what you found and what it means.

# %% [markdown]
# ## Common Mistakes
#
# These are the errors most often made with {{MODULE_NAME}}. Study them carefully.
#
# ### Mistake 1: {{MISTAKE_1_TITLE}}
#
# **What happens:** {{MISTAKE_1_WHAT_HAPPENS}}
#
# **Why it happens:** {{MISTAKE_1_WHY}}
#
# **How to avoid it:** {{MISTAKE_1_HOW_TO_AVOID}}
#
# The cell below demonstrates this mistake and the correction:

# %% [markdown]
# ## Exploration Prompts
#
# Finished early, or want to go deeper? Try modifying the demonstrations above:
#
# 1. **{{EXPLORATION_1}}** — What happens to the output?
# 2. **{{EXPLORATION_2}}** — Does the relationship hold?
# 3. **{{EXPLORATION_3}}** — How does this connect to {{RELATED_CONCEPT}}?
# 4. **{{EXPLORATION_4}}** — What would happen if you used {{DIFFERENT_APPROACH}}?
# 5. **{{EXPLORATION_5}}** — Can you reproduce the result from Example {{N}} in the module README?
#
# Add new code cells below and experiment freely. There's no wrong answer in exploration —
# only questions you haven't answered yet.

# %% [markdown]
# ## Summary and References
#
# ### What We Covered
#
# In this notebook, we:
#
# 1. **Demonstrated** {{SUMMARY_ITEM_1}}
# 2. **Explored interactively** how {{SUMMARY_ITEM_2}} affects {{OUTCOME}}
# 3. **Practiced** {{SUMMARY_ITEM_3}} through exercises
#
# ### Key Takeaways
#
# - {{TAKEAWAY_1}}
# - {{TAKEAWAY_2}}
# - {{TAKEAWAY_3}}
#
# ### Next Steps
#
# - Complete the remaining exercises in `EXERCISES.md`
# - Take the module test: `TEST.md`
# - Explore the next module: [[modules/{{NEXT_MODULE_SLUG}}]]
#
# ### References
#
# - {{REFERENCE_1}}
# - {{REFERENCE_2}}
# - See the full resource list: [../RESOURCES.md](../RESOURCES.md)
#
# ---
#
# _Notebook last updated: {{YYYY-MM-DD}}_
